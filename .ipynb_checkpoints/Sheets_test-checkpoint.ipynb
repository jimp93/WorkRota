# %%
import gspread
from pprint import pprint
import datetime as dt

# %%
from oauth2client.service_account import ServiceAccountCredentials
today = dt.date.today()
today
# Out:
# datetime.date(2021, 9, 14)

# %%
scope=["https://spreadsheets.google.com/feeds",'https://www.googleapis.com/auth/spreadsheets',"https://www.googleapis.com/auth/drive.file","https://www.googleapis.com/auth/drive"]

# %%
creds = ServiceAccountCredentials.from_json_keyfile_name("creds.json", scope)

# %%
client = gspread.authorize(creds)

# %%
sheet=client.open("London newsdesk rotas").get_worksheet(2)

# %%
data=sheet.get_all_values()

# %%
for ra in range(1,30):
    sheet = client.open("London newsdesk rotas").get_worksheet(ra)
    row = sheet.row_values(1)
    str_o_split = row[0].split("-")
    str_m_split = str_o_split[0].split(" ")
    month = str_m_split[0][:3]
    str_date = month + " " + str_m_split[1] + " " + str_split[1][-4:]
    d = dt.datetime.strptime(str_date, '%b %d %Y')
    date_obj = d.date()
    difference = date_obj - today
    if difference > dt.timedelta(days=-7):
        print(d)
    else:
        break


    #row= sheet.row_values(r)
    #print(row)
col = sheet.col_values(3)  # Get a specific column
cell = sheet.cell(1,2).value #
# Out:
# 2021-10-25 00:00:00
# 2021-10-18 00:00:00
# 2021-10-11 00:00:00
# 2021-10-04 00:00:00
# 2021-09-27 00:00:00
# 2021-09-20 00:00:00
# 2021-09-13 00:00:00

# %%
pprint(data)
# Out:
# [['Oct 4-10 2021', '', '', '', '', '', '', '', ''],
#  ['', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', '', 'Sat', 'Sun'],
#  ['7:00 AM', '', '', '', '', '', '', '', ''],
#  ['7:30 AM', 'JWP', 'JWP', 'JWP', 'JWP', 'JWP', '', '', ''],
#  ['9:00 AM',
#   'JIT/CSP/JJ',
#   'JIT/CSP/JJ',
#   'CSP/JJ/JIT?',
#   'CSP/JJ',
#   'CSP/JJ',
#   '',
#   'CSP',
#   'CSP'],
#  ['1:00 PM', 'AM', 'AM', 'AM', 'AM', 'AM', '', '', ''],
#  ['', 'TORY CONF', 'TORY CONF', '', '', '', '', '', ''],
#  ['Holiday', '', '', '', '', '', '', '', ''],
#  ['Recup Earned', '', '', '', '', '', '', 'CSP', 'CSP'],
#  ['Recup used', '', '', '', 'JIT', 'JIT', '', '', '']]
